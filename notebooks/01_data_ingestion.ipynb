# %% [markdown]
# # 01 - Data Ingestion

# %%
# This notebook documents the data ingestion process.
# The actual ETL pipeline is at scripts/etl_pipeline.py

from pathlib import Path
import pandas as pd

PROJECT = Path().resolve().parent
DATA_DIR = PROJECT / "data" / "raw"
print("Raw data directory:", DATA_DIR)

# %%
files = sorted(DATA_DIR.glob("*.csv"))
for f in files:
    df = pd.read_csv(f, nrows=5)
    print(f"\n=== {f.name} ===")
    print(f"Columns: {list(df.columns)}")

# %%
# Run the ETL pipeline
# !python ../scripts/etl_pipeline.py --log-level INFO

# %% [markdown]
# ---
# *Notebook auto-generated for deliverable structure*
